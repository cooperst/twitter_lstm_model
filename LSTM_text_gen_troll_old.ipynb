# %%
import tensorflow as tf
import string
import requests
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, Dropout, Conv1D, MaxPooling1D
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import re 

def remove_urls(text):
    return url_pat.sub('', text).strip()

# %%
import os

def split_file(input, output, max_size = 6 * 1024**2):
    os.makedirs(output, exist_ok=True)
    base = os.path.basename(input)
    part = 0
    current_size = 0
    out = None

    with open(input, "rb") as f:
        for line in f:
            if out is None or current_size + len(line) > max_size:
                if out:
                    out.close()
                part += 1
                out_path = os.path.join(output, f"chunk.part{part:d}.txt")
                out = open(out_path, "wb")
                current_size = 0
            out.write(line)
            current_size += len(line)
    if out:
        print(f"Split {input} into {part} parts")
        out.close()
    return part

# %%
url_pat = re.compile(r'http\S+', flags = re.IGNORECASE)

with open("chunk.part41.txt", "r", encoding = "utf-8") as t:
    text = t.read()
    
data = text.splitlines()
data = [remove_urls(line) for line in data]

# %%
split_troll = split_file("combined_troll.txt", "chunks", max_size = 6 * 1024**2 )
# Out:
# Split combined_troll.txt into 49 parts

# %% [markdown]
# #### LSTM model and train test preparation

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(data) #it's going to fit on the data in the forms of lines.

# %%
encoded_text=tokenizer.texts_to_sequences(data)

# %%
vocab_size=len(tokenizer.word_counts)+1 # always adding plus one for tensorflow

# %% [markdown]
# ### Prepare data for training

# %%
data_list=[]
for i in encoded_text:
    if len(i)>1:
        for j in range(2,len(i)+1):
            data_list.append(i[:j])
#             print(i[:j]) # if you want to check data

# %% [markdown]
# #### Paddding

# %%
max_length=25
#max length of line is 25 token per line

# %%
sequences=pad_sequences(data_list,maxlen=max_length,padding="pre") # we set the lenght size equal to max_length

# %%
X=sequences[:,:-1]
y=sequences[:,-1].astype('int32')

# %%
X.shape, y.shape
# Out:
# ((503222, 24), (503222,))

# %%
seq_length=X.shape[1]

# %% [markdown]
# #### Build Model
# - We will build a simple LSTM model

# %%
model=Sequential()
model.add(Embedding(vocab_size,50)) 
#The first layer is the Embedded layer that uses 50-length vectors
#return_sequences=True because we add another LSTM
model.add(LSTM(100,return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100,activation="relu"))
model.add(Dense(vocab_size,activation="softmax"))

# %%
model.build(input_shape=(None, seq_length))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 24, 50)              │       4,214,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 24, 100)             │          60,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100)                 │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 84294)               │       8,513,694 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,879,294 (49.13 MB)
#  Trainable params: 12,879,294 (49.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.fit(X,y,batch_size=256,epochs=150)
# Out:
# Epoch 1/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 345s 173ms/step - accuracy: 0.0322 - loss: 8.8907
# Epoch 2/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 349s 177ms/step - accuracy: 0.0484 - loss: 8.1567
# Epoch 3/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 331s 168ms/step - accuracy: 0.0614 - loss: 7.7224
# Epoch 4/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 326s 166ms/step - accuracy: 0.0719 - loss: 7.3808
# Epoch 5/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 328s 167ms/step - accuracy: 0.0815 - loss: 7.0727
# Epoch 6/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 309s 157ms/step - accuracy: 0.0906 - loss: 6.7785
# Epoch 7/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 303s 154ms/step - accuracy: 0.0996 - loss: 6.4992
# Epoch 8/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 305s 155ms/step - accuracy: 0.1083 - loss: 6.2248
# Epoch 9/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 335s 170ms/step - accuracy: 0.1183 - loss: 5.9614
# Epoch 10/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.1287 - loss: 5.7110
# Epoch 11/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 308s 157ms/step - accuracy: 0.1404 - loss: 5.4731
# Epoch 12/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 311s 158ms/step - accuracy: 0.1539 - loss: 5.2498
# Epoch 13/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 302s 154ms/step - accuracy: 0.1697 - loss: 5.0441
# Epoch 14/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.1863 - loss: 4.8554
# Epoch 15/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 304s 154ms/step - accuracy: 0.2033 - loss: 4.6895
# Epoch 16/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 314s 160ms/step - accuracy: 0.2208 - loss: 4.5383
# Epoch 17/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 303s 154ms/step - accuracy: 0.2364 - loss: 4.4022
# Epoch 18/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.2520 - loss: 4.2778
# Epoch 19/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 307s 156ms/step - accuracy: 0.2666 - loss: 4.1612
# Epoch 20/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 309s 157ms/step - accuracy: 0.2809 - loss: 4.0506
# Epoch 21/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.2947 - loss: 3.9462
# Epoch 22/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 305s 155ms/step - accuracy: 0.3078 - loss: 3.8481
# Epoch 23/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 308s 156ms/step - accuracy: 0.3206 - loss: 3.7560
# Epoch 24/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 309s 157ms/step - accuracy: 0.3328 - loss: 3.6695
# Epoch 25/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 319s 162ms/step - accuracy: 0.3438 - loss: 3.5871
# Epoch 26/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.3549 - loss: 3.5085
# Epoch 27/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.3662 - loss: 3.4330
# Epoch 28/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 321s 163ms/step - accuracy: 0.3766 - loss: 3.3624
# Epoch 29/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 307s 156ms/step - accuracy: 0.3865 - loss: 3.2947
# Epoch 30/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.3958 - loss: 3.2325
# Epoch 31/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.4048 - loss: 3.1705
# Epoch 32/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 305s 155ms/step - accuracy: 0.4137 - loss: 3.1117
# Epoch 33/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 161ms/step - accuracy: 0.4224 - loss: 3.0561
# Epoch 34/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 311s 158ms/step - accuracy: 0.4302 - loss: 3.0037
# Epoch 35/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 315s 160ms/step - accuracy: 0.4380 - loss: 2.9521
# Epoch 36/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 311s 158ms/step - accuracy: 0.4464 - loss: 2.9022
# Epoch 37/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 314s 160ms/step - accuracy: 0.4536 - loss: 2.8569
# Epoch 38/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.4607 - loss: 2.8100
# Epoch 39/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 308s 157ms/step - accuracy: 0.4673 - loss: 2.7659
# Epoch 40/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.4742 - loss: 2.7245
# Epoch 41/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 309s 157ms/step - accuracy: 0.4807 - loss: 2.6843
# Epoch 42/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 312s 159ms/step - accuracy: 0.4850 - loss: 2.6508
# Epoch 43/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 321s 163ms/step - accuracy: 0.4937 - loss: 2.6050
# Epoch 44/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 309s 157ms/step - accuracy: 0.4991 - loss: 2.5665
# Epoch 45/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 160ms/step - accuracy: 0.5043 - loss: 2.5349
# Epoch 46/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.5100 - loss: 2.5030
# Epoch 47/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 309s 157ms/step - accuracy: 0.5151 - loss: 2.4684
# Epoch 48/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 319s 162ms/step - accuracy: 0.5196 - loss: 2.4399
# Epoch 49/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 160ms/step - accuracy: 0.5242 - loss: 2.4101
# Epoch 50/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 308s 157ms/step - accuracy: 0.5299 - loss: 2.3812
# Epoch 51/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 319s 162ms/step - accuracy: 0.5349 - loss: 2.3527
# Epoch 52/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.5392 - loss: 2.3245
# Epoch 53/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 308s 157ms/step - accuracy: 0.5430 - loss: 2.3008
# Epoch 54/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.5471 - loss: 2.2739
# Epoch 55/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.5523 - loss: 2.2467
# Epoch 56/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 308s 157ms/step - accuracy: 0.5563 - loss: 2.2241
# Epoch 57/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 161ms/step - accuracy: 0.5598 - loss: 2.2010
# Epoch 58/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 320s 163ms/step - accuracy: 0.5628 - loss: 2.1810
# Epoch 59/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 311s 158ms/step - accuracy: 0.5670 - loss: 2.1572
# Epoch 60/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.5714 - loss: 2.1347
# Epoch 61/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 325s 165ms/step - accuracy: 0.5749 - loss: 2.1138
# Epoch 62/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 319s 162ms/step - accuracy: 0.5773 - loss: 2.0977
# Epoch 63/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 312s 159ms/step - accuracy: 0.5808 - loss: 2.0772
# Epoch 64/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 320s 163ms/step - accuracy: 0.5839 - loss: 2.0609
# Epoch 65/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 324s 165ms/step - accuracy: 0.5868 - loss: 2.0424
# Epoch 66/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.5903 - loss: 2.0247
# Epoch 67/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 312s 158ms/step - accuracy: 0.5928 - loss: 2.0053
# Epoch 68/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 157ms/step - accuracy: 0.5966 - loss: 1.9869
# Epoch 69/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.5988 - loss: 1.9735
# Epoch 70/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 312s 158ms/step - accuracy: 0.6019 - loss: 1.9567
# Epoch 71/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.6049 - loss: 1.9398
# Epoch 72/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 324s 165ms/step - accuracy: 0.6066 - loss: 1.9282
# Epoch 73/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6099 - loss: 1.9105
# Epoch 74/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 312s 159ms/step - accuracy: 0.6115 - loss: 1.8982
# Epoch 75/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 334s 165ms/step - accuracy: 0.6144 - loss: 1.8828
# Epoch 76/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 321s 163ms/step - accuracy: 0.6169 - loss: 1.8694
# Epoch 77/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 311s 158ms/step - accuracy: 0.6187 - loss: 1.8570
# Epoch 78/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.6213 - loss: 1.8433
# Epoch 79/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 321s 163ms/step - accuracy: 0.6238 - loss: 1.8302
# Epoch 80/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 320s 163ms/step - accuracy: 0.6261 - loss: 1.8184
# Epoch 81/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 157ms/step - accuracy: 0.6278 - loss: 1.8054
# Epoch 82/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6279 - loss: 1.8011
# Epoch 83/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 324s 165ms/step - accuracy: 0.6332 - loss: 1.7786
# Epoch 84/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 161ms/step - accuracy: 0.6352 - loss: 1.7669
# Epoch 85/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 315s 160ms/step - accuracy: 0.6355 - loss: 1.7604
# Epoch 86/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 329s 167ms/step - accuracy: 0.6368 - loss: 1.7518
# Epoch 87/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 326s 166ms/step - accuracy: 0.6401 - loss: 1.7380
# Epoch 88/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 314s 160ms/step - accuracy: 0.6408 - loss: 1.7316
# Epoch 89/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6428 - loss: 1.7201
# Epoch 90/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.6445 - loss: 1.7097
# Epoch 91/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 320s 163ms/step - accuracy: 0.6462 - loss: 1.7025
# Epoch 92/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 309s 157ms/step - accuracy: 0.6479 - loss: 1.6902
# Epoch 93/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.6501 - loss: 1.6824
# Epoch 94/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 331s 166ms/step - accuracy: 0.6514 - loss: 1.6719
# Epoch 95/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.6526 - loss: 1.6634
# Epoch 96/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 314s 160ms/step - accuracy: 0.6537 - loss: 1.6567
# Epoch 97/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 327s 167ms/step - accuracy: 0.6561 - loss: 1.6463
# Epoch 98/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 323s 164ms/step - accuracy: 0.6568 - loss: 1.6394
# Epoch 99/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 312s 159ms/step - accuracy: 0.6590 - loss: 1.6275
# Epoch 100/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.6602 - loss: 1.6213
# Epoch 101/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 324s 165ms/step - accuracy: 0.6613 - loss: 1.6138
# Epoch 102/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 314s 160ms/step - accuracy: 0.6628 - loss: 1.6061
# Epoch 103/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6644 - loss: 1.5979
# Epoch 104/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 323s 164ms/step - accuracy: 0.6663 - loss: 1.5895
# Epoch 105/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.6667 - loss: 1.5835
# Epoch 106/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 310s 158ms/step - accuracy: 0.6684 - loss: 1.5738
# Epoch 107/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.6697 - loss: 1.5677
# Epoch 108/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 327s 166ms/step - accuracy: 0.6681 - loss: 1.5707
# Epoch 109/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.6728 - loss: 1.5512
# Epoch 110/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.6746 - loss: 1.5410
# Epoch 111/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 327s 166ms/step - accuracy: 0.6745 - loss: 1.5416
# Epoch 112/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 321s 163ms/step - accuracy: 0.6770 - loss: 1.5300
# Epoch 113/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6767 - loss: 1.5275
# Epoch 114/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 319s 162ms/step - accuracy: 0.6774 - loss: 1.5231
# Epoch 115/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 323s 164ms/step - accuracy: 0.6800 - loss: 1.5134
# Epoch 116/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.6802 - loss: 1.5081
# Epoch 117/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6812 - loss: 1.5015
# Epoch 118/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.6831 - loss: 1.4953
# Epoch 119/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.6838 - loss: 1.4914
# Epoch 120/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 321s 163ms/step - accuracy: 0.6851 - loss: 1.4829
# Epoch 121/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 312s 159ms/step - accuracy: 0.6852 - loss: 1.4799
# Epoch 122/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 319s 162ms/step - accuracy: 0.6870 - loss: 1.4711
# Epoch 123/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 327s 166ms/step - accuracy: 0.6875 - loss: 1.4685
# Epoch 124/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 324s 165ms/step - accuracy: 0.6882 - loss: 1.4652
# Epoch 125/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 319s 162ms/step - accuracy: 0.6904 - loss: 1.4557
# Epoch 126/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.6905 - loss: 1.4527
# Epoch 127/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 326s 166ms/step - accuracy: 0.6912 - loss: 1.4495
# Epoch 128/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 320s 163ms/step - accuracy: 0.6926 - loss: 1.4410
# Epoch 129/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 315s 160ms/step - accuracy: 0.6936 - loss: 1.4364
# Epoch 130/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.6944 - loss: 1.4330
# Epoch 131/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 326s 166ms/step - accuracy: 0.6955 - loss: 1.4290
# Epoch 132/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 160ms/step - accuracy: 0.6962 - loss: 1.4208
# Epoch 133/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6972 - loss: 1.4173
# Epoch 134/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 313s 159ms/step - accuracy: 0.6977 - loss: 1.4131
# Epoch 135/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 315s 160ms/step - accuracy: 0.6990 - loss: 1.4104
# Epoch 136/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 322s 164ms/step - accuracy: 0.6992 - loss: 1.4062
# Epoch 137/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 323s 164ms/step - accuracy: 0.7001 - loss: 1.4004
# Epoch 138/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 161ms/step - accuracy: 0.7005 - loss: 1.3947
# Epoch 139/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 324s 165ms/step - accuracy: 0.7017 - loss: 1.3914
# Epoch 140/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 330s 168ms/step - accuracy: 0.7036 - loss: 1.3844
# Epoch 141/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 320s 163ms/step - accuracy: 0.7027 - loss: 1.3853
# Epoch 142/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 318s 162ms/step - accuracy: 0.7042 - loss: 1.3798
# Epoch 143/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 326s 166ms/step - accuracy: 0.7038 - loss: 1.3770
# Epoch 144/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 314s 160ms/step - accuracy: 0.7064 - loss: 1.3674
# Epoch 145/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 314s 160ms/step - accuracy: 0.7065 - loss: 1.3658
# Epoch 146/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 325s 165ms/step - accuracy: 0.7061 - loss: 1.3674
# Epoch 147/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 316s 161ms/step - accuracy: 0.7073 - loss: 1.3578
# Epoch 148/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 320s 163ms/step - accuracy: 0.7068 - loss: 1.3594
# Epoch 149/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.7079 - loss: 1.3541
# Epoch 150/150
# 1966/1966 ━━━━━━━━━━━━━━━━━━━━ 317s 161ms/step - accuracy: 0.7086 - loss: 1.3525

# %% [markdown]
# ### Text Generation

# %%
text_length = 10

def generate_text(input_text, no_lines):
    general_text = []
    original_input = input_text  # keep the original prefix

    for i in range(no_lines):
        text = []
        for _ in range(text_length):
            encoded = tokenizer.texts_to_sequences([input_text])
            encoded = pad_sequences(encoded, maxlen=seq_length, padding="pre")
            y_pred = np.argmax(model.predict(encoded), axis=-1)

            predicted_word = ""
            for word, index in tokenizer.word_index.items():
                if index == y_pred:
                    predicted_word = word
                    break

            input_text = input_text + ' ' + predicted_word
            text.append(predicted_word)

        line = original_input + " " + " ".join(text)
        general_text.append(line)

        input_text = text[-1]

    return general_text

# %%
input_text="me"
text_produced=generate_text(input_text,2)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ['me the heavens addcartoonstohistory of crap and then called gracefully’ israel’s',
#  'me flushing in the jedi with a horse to freedomfest you']

# %%
input_text="i want"
text_produced=generate_text(input_text,3)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ['i want to be represented church of england pastafarianism churchofengland fsm flyingspaghettimonster',
#  'i want fanno leaguer free rememberwhentrump means she rejecteddebatetopics snaps after yellow',
#  'i want sludge spilling from shuttered colo gold mine into the south']

# %%
input_text="corrupt"
text_produced=generate_text(input_text,2)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ['corrupt праздников – ревет веке дело в россии рамаз поляки пожаров',
#  'corrupt science arlines ramp agent an reiner gives in the wh']

# %%
input_text="love"
text_produced=generate_text(input_text,2)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ['love and closing my neighbor had a large rings grabs soldiers',
#  "love burying a man alive who should be 'huge mistake' zuckerberg"]

# %%
input_text="war is peace"
text_produced=generate_text(input_text,2)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ["war is peace is honesty sometimes aint into a visit taster y'all working",
#  'war is peace is the essence of war rejectedweekends slain to destroy resurrect']

# %%
input_text="freedom is slavery"
text_produced=generate_text(input_text,2)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ["freedom is slavery i don't know what you have to be resuscitated thrust",
#  'freedom is slavery transfer – кличко гол вниманию студенческая столкновения вопрос с китаем']

# %%
input_text="ignorance is strength"
text_produced=generate_text(input_text,2)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ['ignorance is strength of the african american pig of the roundabout of the',
#  'ignorance is strength latest the augustine 25 daily thanks to fiftyfiftygirl friendly223 akula']

# %%
input_text="hillary"
text_produced=generate_text(input_text,10)
text_produced
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ['hillary clinton agrees to testify on benghazi emails politics “the islamic',
#  'hillary state dangles marriage bonuses paid honeymoons as perks for joining',
#  'hillary food joe drone no wave that tells guns else and',
#  'hillary i may not be a nazi alt country obamalameduck somethingbigtonumber1',
#  'hillary пристроится обама украина против ирана в сирии © ap photo',
#  'hillary gallery todosmarchamos demonstrators protest cuban government in downtown miami missiles',
#  'hillary жить отменили ответственных с ельциным кругах фото самолета энергетика минобороны',
#  'hillary рф опубликовало видео пусков крылатых ракет с борта ту 160',
#  'hillary paris anytime out official terrorist expect paul take a break',
#  'hillary up the petition of trump conspiracysongs to answer the feet']
